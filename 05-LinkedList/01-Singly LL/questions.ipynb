# %% [markdown]
# ### Reversing a SLL

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0
    
    def __str__(self):
        temp_node = self.head
        result = ''
        while temp_node is not None:
            result += str(temp_node.value)
            if temp_node.next is not None:
                result += ' -> '
            temp_node = temp_node.next
        return result
    
    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1
        
    def reverse(self):
        prev, curr = None, self.head
        while curr:
            nxt = curr.nxt
            curr.next = prev
            prev = curr
            curr = nxt
        return prev

# %% [markdown]
# ### Finding Middle Element

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0
    
    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1
    

    ''' 
    Other Method    
    
    def find_middle(self):
        mid = int((self.length) / 2)
        curr = self.head
        for _ in range(mid):
            curr = curr.next
        return curr.value
    '''

# %% [markdown]
# ### Removing Duplicates

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0
    
    def __str__(self):
        temp_node = self.head
        result = ''
        while temp_node is not None:
            result += str(temp_node.value)
            if temp_node.next is not None:
                result += ' -> '
            temp_node = temp_node.next
        return result
    
    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1
    
    def remove_duplicates(self):
        if self.head is None:
            return
        node_values = set()  # set to store unique node values
        current_node = self.head
        node_values.add(current_node.value)
        while current_node.next:
            if current_node.next.value in node_values:  # duplicate found
                current_node.next = current_node.next.next
                self.length -= 1
            else:
                node_values.add(current_node.next.value)
                current_node = current_node.next
        self.tail = current_node

# %% [markdown]
# ### Merging 2 sorted linked lists

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    def mergeTwoLists(self, list1, list2):
        dummy = ListNode(-1)
        curr = dummy

        while list1 and list2:
            if list1.val <= list2.val:
                curr.next = list1
                list1 = list1.next
            else:
                curr.next = list2
                list2 = list2.next
            curr = curr.next

        if list1:
            curr.next = list1
        else:
            curr.next = list2
        
        return dummy.next

'''
Logic: 

Compare heads → attach smaller node to result → move that list forward
Repeat until one list ends → attach the remaining nodes

dummy created to avoid edge case caused by head
'''
# Out:
# '\nLogic: \n\nCompare heads → attach smaller node to result → move that list forward\nRepeat until one list ends → attach the remaining nodes\n\ndummy created to avoid edge case caused by head\n'

# %% [markdown]
# ### Removing duplicates from sorted list

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def deleteDuplicates(self, head):
        curr = head

        while curr and curr.next:
            if curr.val == curr.next.val:
                curr.next = curr.next.next
            else:
                curr = curr.next
            
        return head

# %% [markdown]
# ### Remove Elements from linked lists

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    def removeElements(self, head, val):
        dummy = ListNode(0)
        dummy.next = head

        curr = dummy

        while curr.next:
            if curr.next.val == val:
                curr.next = curr.next.next
            else:
                curr = curr.next
        
        return dummy.next


'''
The key idea of linked list operations is use create a dummy head to avoid the complications of edge case and set dummy.next to head or whatever the condition is. 
'''
# Out:
# '\nThe key idea of linked list operations is use create a dummy head to avoid the complications of edge case and set dummy.next to head or whatever the condition is. \n'

# %% [markdown]
# ### Palindrom LL

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def isPalindrome(self, head) -> bool:
        # 1. Finding the middle ele
        slow = fast = head

        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next

        # Now slow == middle element

        # 2. Now reversing the second half from the middle
        prev = None
        while slow:
            nxt = slow.next
            slow.next = prev
            prev = slow
            slow = nxt
        
        # 3. Comparing if both first and second halves are equal
        left, right = head, prev

        while right:
            if left.val != right.val:
                return False
            left = left.next
            right = right.next

        return True
